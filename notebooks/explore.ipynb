# %% [markdown]
# # Dataset Organizer Exploration
#
# This notebook is used for exploratory data analysis and testing various data processing and visualization techniques for the dataset organizer project.

# %%
import pandas as pd
from src.organizer import Organizer
from src.visualizer import Visualizer

# Initialize the Organizer and Visualizer
organizer = Organizer()
visualizer = Visualizer()

# %%
# Load the raw data
raw_data = organizer.load_data('data/raw/sample_device_1.csv')
raw_data.head()

# %%
# Clean and organize the data
cleaned_data = organizer.clean_data(raw_data)
organized_data = organizer.organize_by_device(cleaned_data)
organized_data.head()

# %%
# Display the organized data in spreadsheet format
visualizer.display_spreadsheet(organized_data)

# %%
# Display the organized data in graph format
visualizer.display_graph(organized_data)
